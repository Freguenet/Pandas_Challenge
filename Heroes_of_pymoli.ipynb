# %%
import pandas as pd

# %%
file = ("purchase_data.csv")

# %%
pymoli_df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
pymoli_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#player count
total_players = pymoli_df["SN"].nunique()
player_count = {"": [""], 
                "Total Players": [total_players]}
df_player_count = pd.DataFrame(player_count)
df_player_count
# Out:
#      Total Players
# 0              576

# %%
#purchasing annalysis
num_unique = pymoli_df["Item Name"].nunique()
ave_price = pymoli_df["Price"].mean()
num_purchase = pymoli_df["Purchase ID"].count()
total_purchase = pymoli_df["Price"].sum()
purch_annalysis = {"": [""], 
                "Unique Items": [num_unique],
                  "Average Price": [ave_price],
                   "Number of Purchases": [num_purchase],
                  "Total Purchase": [total_purchase]}
df_purchase_annalysis = pd.DataFrame(purch_annalysis)
df_purchase_annalysis
# Out:
#      Unique Items  Average Price  Number of Purchases  Total Purchase
# 0             179       3.050987                  780         2379.77

# %%
#gender demographic
grouped_gender = pymoli_df.groupby("Gender")
grouped_gender_df = pd.DataFrame(grouped_gender["SN"].nunique())

grouped_gender_purch_tot_df = pd.DataFrame(grouped_gender["Purchase ID"].count())
grouped_gender_ave_price_df = pd.DataFrame(grouped_gender["Price"].mean())
grouped_gender_tot_purch_df = pd.DataFrame(grouped_gender["Price"].sum())
total_purch_df = pd.DataFrame(grouped_gender["Price"].sum())
ave_total_purch_pers = pd.DataFrame(grouped_gender["Price"].sum()/grouped_gender["SN"].nunique())


perc_gender = (grouped_gender["SN"].nunique()/num_purchase)*100
perc_gender_df = pd.DataFrame(perc_gender)
merged_gender_df = pd.merge(grouped_gender_df, perc_gender_df, on="Gender")

merged_gender_df
# Out:
#                        SN_x       SN_y
# Gender
# Female                   81  10.384615
# Male                    484  62.051282
# Other / Non-Disclosed    11   1.410256

# %%
purch_annalysis_gender = pd.merge(grouped_gender_purch_tot_df, grouped_gender_ave_price_df, on="Gender").merge(total_purch_df, on="Gender").merge(ave_total_purch_pers, on="Gender")
purch_annalysis_gender_df = pd.DataFrame(purch_annalysis_gender)
# .merge(ave_total_purch_pers, on="Gender")
purch_annalysis_gender_df
# Out:
#                        Purchase ID   Price_x  Price_y         0
# Gender
# Female                         113  3.203009   361.94  4.468395
# Male                           652  3.017853  1967.64  4.065372
# Other / Non-Disclosed           15  3.346000    50.19  4.562727

# %% [raw]
# df_grouped_by_gender = pd.DataFrame(grouped_by_gender.count())
# df_grouped_by_gender.rename(columns={"Purchase ID"}: {"Purchase Count"})
# df_grouped_by_gender.head()

# %%
#second gender

# %%
#Demo
print(pymoli_df["Age"].max())
print(pymoli_df["Age"].min())
# Out:
# 45
# 7

# %%
bins = [0,9, 14, 19, 24, 29, 34, 39, 45]

group_labels = ["< 10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
pd.cut(pymoli_df["Age"], bins, labels=group_labels).head()
pymoli_df["Age Group"] = pd.cut(pymoli_df["Age"], bins, labels=group_labels)
pymoli_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                          Frenzied Scimitar   1.56       40+
# 2                               Final Critic   4.88     20-24
# 3                                Blindscythe   3.27     20-24
# 4                                       Fury   1.44     20-24

# %%
player_age = pymoli_df.groupby("Age Group")

player_age_df = pd.DataFrame(player_age["SN"].nunique())
player_age_df 
perc_age = (player_age["SN"].nunique()/total_players)*100
perc_age_df = pd.DataFrame(perc_age)
perc_age_df
merged_age_perc = pd.merge(player_age_df, perc_age_df, on="Age Group")
merged_age_perc
# Out:
#            SN_x       SN_y
# Age Group
# < 10         17   2.951389
# 10-14        22   3.819444
# 15-19       107  18.576389
# 20-24       258  44.791667
# 25-29        77  13.368056
# 30-34        52   9.027778
# 35-39        31   5.381944
# 40+          12   2.083333

# %%
#Purch annalysis by age
player_age_ave_purch_df = pd.DataFrame(player_age["Price"].mean())
#player_age_ave_purch_df
player_age_sum_purch_df = pd.DataFrame(player_age["Price"].sum())
#player_age_sum_purch_df
player_age_ave_person_purch = player_age["Price"].sum()/player_age["SN"].nunique()#comeback
player_age_ave_person_purch_df = pd.DataFrame(player_age_ave_person_purch)
player_age_ave_person_purch_df
#a revoir
# Out:
#                   0
# Age Group
# < 10       4.537059
# 10-14      3.762727
# 15-19      3.858785
# 20-24      4.318062
# 25-29      3.805195
# 30-34      4.115385
# 35-39      4.763548
# 40+        3.186667

# %%
purch_annalysis_age = pd.merge(player_age_df, player_age_ave_purch_df, on="Age Group").merge(player_age_sum_purch_df, on="Age Group").merge(player_age_ave_person_purch_df, on="Age Group")
purch_annalysis_age_df = pd.DataFrame(purch_annalysis_age)
purch_annalysis_age_df
# Out:
#             SN   Price_x  Price_y         0
# Age Group
# < 10        17  3.353478    77.13  4.537059
# 10-14       22  2.956429    82.78  3.762727
# 15-19      107  3.035956   412.89  3.858785
# 20-24      258  3.052219  1114.06  4.318062
# 25-29       77  2.900990   293.00  3.805195
# 30-34       52  2.931507   214.00  4.115385
# 35-39       31  3.601707   147.67  4.763548
# 40+         12  2.941538    38.24  3.186667

# %%
#top spender
grouped_total_players = pymoli_df.groupby("SN")

purchase_count_df = pd.DataFrame(grouped_total_players["Price"].count())
ave_top_purch_price_df = pd.DataFrame(grouped_total_players["Price"].mean())
total_top_purch_price_df = pd.DataFrame(grouped_total_players["Price"].sum())
tops_spender_annalysis = pd.merge(purchase_count_df, ave_top_purch_price_df, on="SN").merge(total_top_purch_price_df, on="SN")
tops_spender_annalysis_df = pd.DataFrame(tops_spender_annalysis)

top_spender_df = pd.DataFrame(tops_spender_annalysis_df.sort_values(by=["Price"],ascending=False))
top_spender_df[:5]
# Out:
#              Price_x   Price_y  Price
# SN
# Lisosia93          5  3.792000  18.96
# Idastidru52        4  3.862500  15.45
# Chamjask73         3  4.610000  13.83
# Iral74             4  3.405000  13.62
# Iskadarya95        3  4.366667  13.10

# %%
gouped_items = pymoli_df.groupby("Item ID").agg({"Item Name":"first"}, {"Price":"sum"})
print (grouped_items)
#pop_item_df = pd.Data.Frame(grouped_items["Item Name"])
#pop_purch_count_df = pd.Data.Frame(grouped_items["Purchase ID"].count())
#pop_item_price_df = pd.Data.Frame(grouped_items["Price"])


# In [8]: df = pd.DataFrame({"A": range(4), "B": ["PO", "PO", "PA", "PA"], "C": ["Est1", "Est2", "West1", "West2"]})

# In [9]: df.groupby('B').agg({'A':'sum', 'C':'first'})
# Out[9]:
#         C  A
# B
# PA  West1  5
# PO   Est1  1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-bb25a4091292> in <module>
#       1 gouped_items = pymoli_df.groupby("Item ID").agg({"Item Name":"first"}, {"Price":"sum"})
# ----> 2 print (grouped_items)
#       3 #pop_item_df = pd.Data.Frame(grouped_items["Item Name"])
#       4 #pop_purch_count_df = pd.Data.Frame(grouped_items["Purchase ID"].count())
#       5 #pop_item_price_df = pd.Data.Frame(grouped_items["Price"])
#
# NameError: name 'grouped_items' is not defined
